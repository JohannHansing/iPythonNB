# %%
# %matplotlib inline
import numpy as np
import sys
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# %%
# from mpl_toolkits.mplot3d import axes3d
# file = open('trajectory.txt','r')
# all_lines = file.readlines()
# i=0
# new_data = []
# for i in xrange(len(all_lines[::1])):
#     new_data.append([float(x) for x in all_lines[i].split()])
# file.close()
def readhistofile(filename):
    histofile = open(filename,'r')
    lines = histofile.readlines()
    histodata = []
    tmpdat = []
    count=0
    maxVal = int(lines[-1].split()[1])
    for line in lines[:-2]:
        if str(line.split()[0]) == 'X':
            histodata.append(tmpdat)
            tmpdat = []
            count+=1
        else:
            tmpdat.append([float(x)/maxVal for x in line.split()])
    histofile.close()
    if count != 99:
        print "Count not 99!"
    return histodata

histodataNoHI = readhistofile('/Users/jh/Documents/workspace-cpp/SingleParticleSimulation/Release/sim_data/noreset/steric/dt0.0001/t100/d0/b10/p2/k1.000/u0/InstantValues/posHistoMatrix.txt')
histodataHI = readhistofile('HistoHI/posHistoMatrixHI.txt')
histodataETa15nS = readhistofile('HistoHI/posHistoMatrixa1.5nS.txt')
histodataNoEwald = readhistofile('HistoHI/posHistoMatrixNoEwald.txt')
histodataNoEwaldNoL = readhistofile('HistoHI/posHistoMatrixnEnL.txt')
histodataNoS = readhistofile('HistoHI/posHistoMatrixnS.txt')
histodataNoEwaldET = readhistofile('HistoHI/posHistoMatrixNoEwaldET.txt')
histodatanEnS=readhistofile('HistoHI/posHistoMatrixnEnSp2.txt')
histodataET = readhistofile('HistoHI/posHistoMatrixET.txt')
histodatanL = readhistofile('HistoHI/posHistoMatrixnL.txt')
histodataETnLSteric = readhistofile('HistoHI/posHistoMatrixETn1nLSteric.txt')
histodataPOWnL = readhistofile('HistoHI/posHistoMatrixPOWnL.txt')
histodataPOW = readhistofile('HistoHI/posHistoMatrixPOW.txt')
histodatafullMM = readhistofile('HistoHI/posHistoMatrixfullMM.txt')
histodataETn1nEnL = readhistofile('HistoHI/posHistoMatrixETn1nEnL.txt')
histodatanEnLa21 = readhistofile('HistoHI/posHistoMatrixnEnLa2.1.txt')
histodataET2nEnL = readhistofile('HistoHI/posHistoMatrixET2nLnE.txt')
histodataET3nEnL = readhistofile('HistoHI/posHistoMatrixET3nLnE.txt')
histodataET4nEnL = readhistofile('HistoHI/posHistoMatrixET4nLnE.txt')
histodataET4nEnLa05 = readhistofile('HistoHI/posHistoMatrixET4nLnEa05.txt')
histodataET3nL = readhistofile('HistoHI/posHistoMatrixET3nL.txt')   #TODO Reload with better data soon
histodataET3n2nLnE = readhistofile('HistoHI/posHistoMatrixET3n2nLnE.txt')
histodataET3nL = readhistofile('HistoHI/posHistoMatrixETn3nL.txt')

# %%
import numpy.linalg as LA
def is_pos_def(x):
    return np.all(np.linalg.eigvals(x) > 0)

mat = np.asarray([
 [-0.374123 , 0.335658 ,  3.41156],
 [0.335658 ,  2.00618 ,-0.602338],
  [3.41156, -0.602337 ,  -2.4776]
])
print(is_pos_def(mat))
print(LA.inv(mat))
# Out:
# False
# [[ 0.23751743  0.05447842  0.31380794]
#  [ 0.05447857  0.47704651 -0.04096155]
#  [ 0.31380793 -0.04096157  0.03844336]]

# %%
diff_list = [["-asdfsadf"],['+asdfsaf'],['sadfsl']]
for x in diff_list:
    if ("+" in x[0]) or ("-" in x[0]):
        print x
# Out:
# ['-asdfsadf']
# ['+asdfsaf']

# %%
N=100
x = y =np.arange(0, 10, 10./N)
z0=40
ZHInEET=histodataNoEwaldET[0][z0]
ZHIET=histodataET[0][z0]
ZHInEnS=histodatanEnS[50][z0]

plt.figure(figsize=(7,6))
plt.plot(x,ZHInEET)
plt.plot(x,ZHIET)
plt.plot(x,ZHInEnS)
plt.legend(['ET nEw','ET','No Ewald no Steric p=2'], loc='lower center')
plt.axis([0, 10, 0, 1])
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
# ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)

# plt.show()
# Out:
# [0, 10, 0, 1]

# %%
x = y =np.arange(0, 10, 10./N)
z0=30
ZHI=histodataHI[0][z0]
ZnHI=histodataNoHI[0][z0]
ZHINoE=histodataNoEwald[0][z0]
ZHINoEnL=histodataNoEwaldNoL[0][z0]
ZHIET=histodataET[0][z0]
ZHInL=histodatanL[0][z0]
ZHIPOW=histodataPOW[0][z0]
ZHIfulMM=histodatafullMM[0][z0]



plt.figure(figsize=(7,6))
plt.plot(x,ZnHI)
plt.plot(x,ZHINoE)
plt.plot(x,ZHINoEnL)
plt.plot(x,ZHIfulMM)
plt.plot(x,ZHIPOW)
plt.legend(['no HI','no Ewald','no Ewald no Lub','full MM','POW with S'], loc='lower center')
plt.axis([0, 10, 0, 1])
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
# ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)

# plt.show()
# Out:
# [0, 10, 0, 1]

# %%
x = y =np.arange(0, 1, 1./N)
z0=30
ZnHI=histodataNoHI[0][z0]
ZHIPOW=histodataPOW[0][z0]



plt.figure(figsize=(5,4))
plt.plot(x,ZnHI,label='no HI')
plt.plot(x,ZHIPOW,label='with HI')
plt.legend(loc='lower center')
plt.axis([0, 1., 0, 1])
plt.xlabel("$x/b$")
plt.ylabel("Intensity [a.u.]")
pp = PdfPages('figures/HistoHI.pdf')
pp.savefig(bbox_inches='tight')
pp.close()

# %%
z0 = 10
gridET = np.ravel(np.asarray(histodataET[z0])).reshape((N, N))
gridnL = np.ravel(np.asarray(histodatanL[z0])).reshape((N, N))
gridETnLS = np.ravel(np.asarray(histodataETnLSteric[z0])).reshape((N, N))
gridPOWnL = np.ravel(np.asarray(histodataPOWnL[z0])).reshape((N, N))
gridPOW = np.ravel(np.asarray(histodataPOW[z0])).reshape((N, N))
gridfullMM = np.ravel(np.asarray(histodatafullMM[z0])).reshape((N, N))
gridETn1nEnL = np.ravel(np.asarray(histodataETn1nEnL[z0])).reshape((N, N))
gridnEnLa21 = np.ravel(np.asarray(histodatanEnLa21[z0])).reshape((N, N))


fig2, (ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8) = plt.subplots(8, figsize=(6,27))
colormap=plt.get_cmap('YlGnBu')

ax1.set_title('HI ETest no Steric')
ax1.imshow(gridET, extent=(0,10, 0,10),
           interpolation='nearest', cmap=colormap)

ax2.set_title('HI no Lub')
ax2.imshow(gridnL, extent=(0,10, 0,10),
           interpolation='nearest', cmap=colormap)

ax3.set_title('ETn1 + steric, no Lub')
ax3.imshow(gridETnLS, extent=(0,10, 0,10),
           interpolation='nearest', cmap=colormap)

ax4.set_title('POW no Lub')
ax4.imshow(gridPOWnL, extent=(0,10, 0,10),
           interpolation='nearest', cmap=colormap)

ax5.set_title('POW with Steric')
ax5.imshow(gridPOW, extent=(0,10, 0,10),
           interpolation='nearest', cmap=colormap)

ax6.set_title('full Mobility Matrix no Lub')
ax6.imshow(gridfullMM, extent=(0,10, 0,10),
           interpolation='nearest', cmap=colormap)

ax7.set_title('ET n1 nE nL')
ax7.imshow(gridETn1nEnL, extent=(0,10, 0,10),
           interpolation='nearest', cmap=colormap)

ax8.set_title('no E no Lub a=2.1')
ax8.imshow(gridnEnLa21, extent=(0,10, 0,10),
           interpolation='nearest', cmap=colormap)

plt.tight_layout()
plt.show()

# %%
z0 = 10
gridNoHI = np.ravel(np.asarray(histodataNoHI[z0])).reshape((N, N))
gridET = np.ravel(np.asarray(histodataET[z0])).reshape((N, N))
gridnL = np.ravel(np.asarray(histodatanL[z0])).reshape((N, N))
gridETnLS = np.ravel(np.asarray(histodataETnLSteric[z0])).reshape((N, N))
gridPOWnL = np.ravel(np.asarray(histodataPOWnL[z0])).reshape((N, N))
gridPOW = np.ravel(np.asarray(histodataPOW[z0])).reshape((N, N))
gridfullMM = np.ravel(np.asarray(histodatafullMM[z0])).reshape((N, N))
gridETn1nEnL = np.ravel(np.asarray(histodataETn1nEnL[z0])).reshape((N, N))
gridnEnLa21 = np.ravel(np.asarray(histodatanEnLa21[z0])).reshape((N, N))


fig2, (ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8) = plt.subplots(8, figsize=(6,27))


ax1.set_title('No HI')
ax1.imshow(gridNoHI, extent=(0,10, 0,10),
           interpolation='nearest', cmap=colormap)

ax2.set_title('HI no Lub')
ax2.imshow(gridnL, extent=(0,10, 0,10),
           interpolation='nearest', cmap=colormap)

ax3.set_title('ETn1 + steric, no Lub')
ax3.imshow(gridETnLS, extent=(0,10, 0,10),
           interpolation='nearest', cmap=colormap)

ax4.set_title('POW no Lub')
ax4.imshow(gridPOWnL, extent=(0,10, 0,10),
           interpolation='nearest', cmap=colormap)

ax5.set_title('POW with Steric')
ax5.imshow(gridPOW, extent=(0,10, 0,10),
           interpolation='nearest', cmap=colormap)

ax6.set_title('full Mobility Matrix no Lub')
ax6.imshow(gridfullMM, extent=(0,10, 0,10),
           interpolation='nearest', cmap=colormap)

ax7.set_title('ET n1 nE nL')
ax7.imshow(gridETn1nEnL, extent=(0,10, 0,10),
           interpolation='nearest', cmap=colormap)

ax8.set_title('no E no Lub a=2.1')
ax8.imshow(gridnEnLa21, extent=(0,10, 0,10),
           interpolation='nearest', cmap=colormap)

plt.tight_layout()
plt.show()
